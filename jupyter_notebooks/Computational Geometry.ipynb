# %%
from scipy.spatial import ConvexHull, convex_hull_plot_2d
import matplotlib.pyplot as plt
import numpy as np

# %%
points = np.random.rand(30, 2)   # 30 random points in 2-D
hull = ConvexHull(points)

# %%
print(points[:,0])
# Out:
# [0.49330144 0.5459466  0.37326831 0.04704159 0.5786955  0.20066903
#  0.98808918 0.05499062 0.5878663  0.17506138 0.53119651 0.92524368
#  0.35318945 0.50255777 0.78550496 0.82743783 0.80751876 0.46130281
#  0.43753522 0.27363598 0.20907568 0.56638768 0.24008471 0.60591564
#  0.92890927 0.4613541  0.69839727 0.70993547 0.4949344  0.81057308]

# %%
print(points[:,1])
# Out:
# [0.21673861 0.83491412 0.79764765 0.72049749 0.07314928 0.37563082
#  0.86773655 0.00637942 0.0956595  0.73759721 0.3939228  0.4892117
#  0.42182437 0.24904543 0.09116243 0.32656902 0.22037202 0.06054913
#  0.64426772 0.69580317 0.26636901 0.49978492 0.5896411  0.5690293
#  0.95191082 0.26095221 0.68458209 0.23213265 0.6266889  0.10591469]

# %%
plt.plot(points[:,0], points[:,1], 'o')
print(hull.simplices)
for simplex in hull.simplices:
    plt.plot(points[simplex, 0], points[simplex, 1], 'y-')
# Out:
# [[17  1]
#  [ 8 27]
#  [12  1]
#  [12 27]
#  [13  3]
#  [23  3]
#  [23  8]
#  [ 9 17]
#  [ 9 13]]
